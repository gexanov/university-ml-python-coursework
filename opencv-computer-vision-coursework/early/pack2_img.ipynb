# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image = np.zeros((50, 50))
plt.imshow(image)
plt.show()

image[:10, 10:20] = 1
plt.imshow(image)
plt.colorbar()
plt.show()


#plt.colorbar()  # Показать соответствие цвета и значения

# %%
plt.imshow(image, cmap='gray')  # устанавливаем серый оттенок (black & white)



image = np.fromfunction(lambda y, x: x, shape=(50, 50))

# %%
image = np.fromfunction(lambda y, x: x + y / 2, shape=(50, 50))
plt.imshow(image, cmap='gray')

# %%
image_rgb = np.stack([image, image, image], axis=-1)
plt.imshow(image_rgb)
plt.colorbar()
plt.show()




image_rgb = np.stack([image, image, image], axis=-1)
image_rgb = (image_rgb / image_rgb.max()) * 255
image_rgb = image_rgb.astype(np.uint8)
plt.imshow(image_rgb)
plt.colorbar()
plt.show()

# 1 канал - красный, 2 - зелёный, 3 - синий
for i in range(3):
    image_out = np.zeros_like(image_rgb)  # Копирование размера и типа данных
    image_out[:, :, i] = image_rgb[:, :, i]
    
    plt.subplot(1, 3, i+1)
    plt.title(f'{image_out[-1, -1]}')
    plt.imshow(image_out)

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..73.5].

# %%
for i in range(3):
    image_out = image_rgb.copy()
    image_out[:, :, i] = 0  # Зануляем один из каналов
    
    plt.subplot(1, 3, i+1)
    plt.title(f'{image_out[-1, -1]}')
    plt.imshow(image_out)

plt.show()

# %%
img = cv2.imread('images/cv.jpg')

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("cv.jpg")   # замени на своё имя файла
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(196.5), np.float64(195.5), np.float64(-0.5))

# %%
plt.imshow(img)
plt.title('Result')
plt.axis('off')  # Скрываем ось координат
plt.show()

# %%
print(img.size)   # (width, height)
print(img.mode)   # RGB, L и т.д.
# Out:
# (197, 196)
# RGB

# %%
import numpy as np

img_np = np.array(img)
print(img_np.shape)
# Out:
# (196, 197, 3)

# %%
img = Image.open("cv.jpg")
img = np.array(img)              # <-- преобразование
img = cv2.resize(img, (300, 500))
print(img.shape)
plt.imshow(img)
# Out:
# (500, 300, 3)

# %%
img = Image.open("cv.jpg")
img = np.array(img) 
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # цветное изображение в серое
plt.imshow(img)

# %%
img = Image.open("cv.jpg")
img = np.array(img) 
img = cv2.cvtColor(img, cv2.COLOR_HSV2BGR) # цветное изображение в серое
plt.imshow(img)

# %%
print(9)
# Out:
# 9

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("cv.jpg")
b, g, r = cv2.split(img)

plt.imshow(b, cmap="gray")
plt.axis("off")
plt.show()
plt.imshow(g, cmap="gray")
plt.axis("off")
plt.show()
plt.imshow(r, cmap="gray")
plt.axis("off")
plt.show()

# %%
img = cv2.merge([b, g, r])

# %%
plt.show()
